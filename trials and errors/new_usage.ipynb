# %% [markdown]
# # FMA: A Dataset For Music Analysis
#
# Michaël Defferrard, Kirell Benzi, Pierre Vandergheynst, Xavier Bresson, EPFL LTS2.
#
# ## Usage
#
# 1. Go through the [paper] to understand what the data is about.
# 1. Download some datasets from <https://github.com/mdeff/fma>.
# 1. Uncompress the archives, e.g. with `unzip fma_small.zip`.
# 1. Load and play with the data in this notebook.
#
# [paper]: https://arxiv.org/abs/1612.01840

# %%
# %matplotlib inline

import os

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import librosa # for audio and music analysis
import librosa.display
import csv
import math
import datatables
import ast
from mpl_toolkits.mplot3d import Axes3D

import utils

plt.rcParams['figure.figsize'] = (17, 5)

# %% [markdown]
# tracks = pd.read_csv('tracks.csv', index_col=0, header=[0, 1], encoding="ISO-8859-1")
# #tracks = tracks[0:5,:]
# tracks = tracks[1:10]
# tracks
# #tracks.shape
# #a[isnan(a)] = 0

# %% [markdown]
# tracks[('track', 'favorites')] = tracks[('track', 'favorites')].map(ast.literal_eval)

# %% [markdown]
# a = a.replace('',np.nan, regex=True)
# a1 = a.dropna()
# #a[('track', 'genres_top')].head(20)
# a1.head(20)

# %%
# Directory where mp3 are stored.
AUDIO_DIR = os.environ.get('AUDIO_DIR')

# Load metadata and features.
tracks = utils.load('tracks.csv')
genres = utils.load('genres.csv')
features = utils.load('features.csv')
echonest = utils.load('echonest.csv')

np.testing.assert_array_equal(features.index, tracks.index)
assert echonest.index.isin(tracks.index).all()

tracks.shape, 
genres.shape, features.shape, echonest.shape
# Out:
# /Users/liguo/Desktop/17-18Fall/2.CS229/5.Projects/Music_Analysis/github_analysis/fma-master/utils.py:220: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   'category', categories=SUBSETS, ordered=True)
# ((163, 4), (106574, 518), (13129, 249))

# %% [markdown]
# ## 1 Metadata
#
# The metadata table, a CSV file in the `fma_metadata.zip` archive, is composed of many colums:
# 1. The index is the ID of the song, taken from the website, used as the name of the audio file.
# 2. Per-track, per-album and per-artist metadata from the Free Music Archive website.
# 3. Two columns to indicate the subset (small, medium, large) and the split (training, validation, test).

# %%
ipd.display(tracks['track'].head())
ipd.display(tracks['album'].head())
ipd.display(tracks['artist'].head())
ipd.display(tracks['set'].head())
# Out:
#           bit_rate  comments   composer        date_created date_recorded  \
# track_id
# 2           256000         0        NaN 2008-11-26 01:48:12    2008-11-26
# 3           256000         0        NaN 2008-11-26 01:48:14    2008-11-26
# 5           256000         0        NaN 2008-11-26 01:48:20    2008-11-26
# 10          192000         0  Kurt Vile 2008-11-25 17:49:06    2008-11-26
# 20          256000         0        NaN 2008-11-26 01:48:56    2008-01-01
#
#           duration  favorites genre_top     genres         genres_all  \
# track_id
# 2              168          2   Hip-Hop       [21]               [21]
# 3              237          1   Hip-Hop       [21]               [21]
# 5              206          6   Hip-Hop       [21]               [21]
# 10             161        178       Pop       [10]               [10]
# 20             311          0       NaN  [76, 103]  [17, 10, 76, 103]
#
#          information  interest language_code  \
# track_id
# ...

# %%
ipd.display(features.head())

# %%
len(tracks[('track', 'genre_top')].unique()) #17
print(tracks[('track', 'genre_top')].unique())

# %% [markdown]
# ## 2 Genres
#
# The genre hierarchy is stored in `genres.csv` and distributed in `fma_metadata.zip`.

# %%
print('{} top-level genres'.format(len(genres['top_level'].unique())))

genres.loc[genres['top_level'].unique()].sort_values('#tracks', ascending=False)
# Out:
# 16 top-level genres
#           #tracks  parent                title  top_level
# genre_id
# 38          38154       0         Experimental         38
# 15          34413       0           Electronic         15
# 12          32923       0                 Rock         12
# 1235        14938       0         Instrumental       1235
# 10          13845       0                  Pop         10
# 17          12706       0                 Folk         17
# 21           8389       0              Hip-Hop         21
# 2            5271       0        International          2
# 4            4126       0                 Jazz          4
# 5            4106       0            Classical          5
# 9            1987       0              Country          9
# 20           1876       0               Spoken         20
# 3            1752       0                Blues          3
# 14           1499       0             Soul-RnB         14
# 8             868       0  Old-Time / Historic          8
# ...

# %%
#genres.loc[genres['top_level'].unique()].sort_values('#tracks', ascending=False)
genres.sort_values('#tracks').head(10)
# Out:
#           #tracks  parent                     title  top_level
# genre_id
# 175             0      86                 Bollywood          2
# 178             0       4                    Be-Bop          4
# 377             1      19                 Deep Funk         14
# 173             4      86     N. Indian Traditional          2
# 493             4     651             Western Swing          9
# 374             9      20                    Banter         20
# 808            12      46                     Salsa          2
# 174            17      86  South Indian Traditional          2
# 465            18      20           Musical Theater         20
# 176            23       2                   Pacific          2

# %% [markdown]
# ## 3 Features
#
# 1. Features extracted from the audio for all tracks.
# 2. For some tracks, data colected from the [Echonest](http://the.echonest.com/) API.

# %%
print('{1} features for {0} tracks'.format(*features.shape))

columns = ['mfcc', 'chroma_cens', 'tonnetz', 'spectral_contrast']
columns.append(['spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff'])
columns.append(['rmse', 'zcr'])
print(len(columns))

for column in columns:
    ipd.display(features[column].head().style.format('{:.2f}'))
# Out:
# 518 features for 106574 tracks
# 6
# <style  type="text/css" >
# </style>
# <table id="T_54f7f6c6_d6fe_11e7_8def_8c85901efc55" >
# <thead>    <tr>
#         <th class="index_name level0" >statistics</th>
#         <th class="col_heading level0 col0" colspan=20>kurtosis</th>
#         <th class="col_heading level0 col20" colspan=20>max</th>
#         <th class="col_heading level0 col40" colspan=20>mean</th>
#         <th class="col_heading level0 col60" colspan=20>median</th>
#         <th class="col_heading level0 col80" colspan=20>min</th>
#         <th class="col_heading level0 col100" colspan=20>skew</th>
#         <th class="col_heading level0 col120" colspan=20>std</th>
#     </tr>    <tr>
#         <th class="index_name level1" >number</th>
#         <th class="col_heading level1 col0" >01</th>
#         <th class="col_heading level1 col1" >02</th>
#         <th class="col_heading level1 col2" >03</th>
#         <th class="col_heading level1 col3" >04</th>
# ...

# %%
print(columns)

# %% [markdown]
# ### 3.1 Echonest features

# %%
print('{1} features for {0} tracks'.format(*echonest.shape))
ipd.display(echonest['echonest', 'metadata'].head())
ipd.display(echonest['echonest', 'audio_features'].head())
ipd.display(echonest['echonest', 'social_features'].head())
ipd.display(echonest['echonest', 'ranks'].head())
# Out:
# 249 features for 13129 tracks
#           album_date         album_name  artist_latitude  \
# track_id
# 2                NaN                NaN          32.6783
# 3                NaN                NaN          32.6783
# 5                NaN                NaN          32.6783
# 10        2008-03-11  Constant Hitmaker          39.9523
# 134              NaN                NaN          32.6783
#
#                artist_location  artist_longitude artist_name  \
# track_id
# 2                  Georgia, US          -83.2230        AWOL
# 3                  Georgia, US          -83.2230        AWOL
# 5                  Georgia, US          -83.2230        AWOL
# 10        Philadelphia, PA, US          -75.1624   Kurt Vile
# 134                Georgia, US          -83.2230        AWOL
#
#                        release
# track_id
# 2         AWOL - A Way Of Life
# 3         AWOL - A Way Of Life
# 5         AWOL - A Way Of Life
# 10           Constant Hitmaker
# ...

# %%
ipd.display(echonest['echonest', 'temporal_features'].head())
x = echonest.loc[2:134, ('echonest', 'temporal_features')]
print(x.shape)
plt.plot(x.T);
# Out:
#                000       001       002       003       004       005  \
# track_id
# 2         0.877233  0.588911  0.354243  0.295090  0.298413  0.309430
# 3         0.534429  0.537414  0.443299  0.390879  0.344573  0.366448
# 5         0.548093  0.720192  0.389257  0.344934  0.361300  0.402543
# 10        0.311404  0.711402  0.321914  0.500601  0.250963  0.321316
# 134       0.610849  0.569169  0.428494  0.345796  0.376920  0.460590
#
#                006       007       008       009     ...           214  \
# track_id                                             ...
# 2         0.304496  0.334579  0.249495  0.259656     ...     -1.992303
# 3         0.419455  0.747766  0.460901  0.392379     ...     -1.582331
# 5         0.434044  0.388137  0.512487  0.525755     ...     -2.288358
# 10        0.734250  0.325188  0.373012  0.235840     ...     -3.662988
# 134       0.401371  0.449900  0.428946  0.446736     ...     -1.452696
#
# ...

# %% [markdown]
# ### 3.2 Features like MFCCs are discriminant

# %%
small = tracks['set', 'subset'] <= 'small'
#X = features.loc[small & (genre1 | genre2), 'mfcc']

# %%
#str[tracks['track', 'genre_top']].map(lambda genres: 1235 in genres)
#print(tracks['track', 'genre_top'].shape)
tracks['track', 'genre_top'] = tracks['track', 'genre_top'].replace(np.nan, 'NaN', regex=True)
tracks['track', 'genre_top'].map(lambda x: type(x)).head()
#tracks['track', 'genre_top']
#genres['title']
# Out:
# track_id
# 2     <class 'str'>
# 3     <class 'str'>
# 5     <class 'str'>
# 10    <class 'str'>
# 20    <class 'str'>
# Name: (track, genre_top), dtype: object

# %%
small = tracks['set', 'subset'] <= 'small'
#print(tracks['track', 'genre_top'].shape)
#print(genres)

# return true/false
def select(genre):
    return tracks['track', 'genre_top'].map(lambda genres: genre in genres)


# map(lambda genres: genre in genres) return true or false on a vector; tracks['track', 'genre_top'] is a vector
# genre in tracks corresponding to features.
genre1 = select('Instrumental')  # Instrumental. 1235
genre2 = select('Hip-Hop')  # Hip-Hop. 21

# subset: small; genre: Instrumental or Hip-Hop, and mfcc.
X = features.loc[small & (genre1 | genre2), 'mfcc']
# Fit the model with X and apply the dimensionality reduction on X.
X = skl.decomposition.PCA(n_components=3).fit_transform(X)

# Encode labels with value between 0 and n_classes-1.
y = tracks.loc[small & (genre1 | genre2), ('track', 'genre_top')]
y = skl.preprocessing.LabelEncoder().fit_transform(y)

plt.scatter(X[:,0], X[:,1], X[:,2], c=y, cmap='RdBu', alpha=0.5)
plt.legend(['PCA1', 'PCA2'], ncol = 2, loc= 'lower right')
X.shape, y.shape
plt.savefig('PCA.pdf')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/collections.py:836: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs=X[:,0], ys = X[:,1], zs=X[:,2], zdir='z', c=y,  cmap='winter')
ax.set_xlim(-300, 550)
ax.set_ylim(-600, 250)
ax.set_zlim(-100, 170)
#plt.show()
plt.savefig('PCA.jpg')

# %%
tracks[('track', 'genre_top')].unique()
# Out:
# array(['Hip-Hop', 'Pop', 'NaN', 'Rock', 'Experimental', 'Folk', 'Jazz',
#        'Electronic', 'Spoken', 'International', 'Soul-RnB', 'Blues',
#        'Country', 'Classical', 'Old-Time / Historic', 'Instrumental',
#        'Easy Listening'], dtype=object)

# %%
X = features.loc[small & (genre1 | genre2), 'mfcc']
print(X.shape)
X = skl.decomposition.PCA(n_components=2).fit_transform(X)
print(X.shape)
y = tracks.loc[small & (genre1 | genre2), ('track', 'genre_top')]
print(y.unique())
y = skl.preprocessing.LabelEncoder().fit_transform(y)
print(y)
# Out:
# (2000, 140)
# (2000, 2)
# ['Hip-Hop' 'Instrumental']
# [0 0 0 ..., 0 0 0]

# %%
tracks['track', 'genre_top'][1:10]
# Out:
# track_id
# 3      Hip-Hop
# 5      Hip-Hop
# 10         Pop
# 20         NaN
# 26         NaN
# 30         NaN
# 46         NaN
# 48         NaN
# 134    Hip-Hop
# Name: (track, genre_top), dtype: object

# %% [markdown]
# ## 5 Genre classification

# %% [markdown]
# ### 5.1 From features

# %%
#small
small = tracks['set', 'subset'] <= 'small'

train = tracks['set', 'split'] == 'training'
val = tracks['set', 'split'] == 'validation'
test = tracks['set', 'split'] == 'test'

y_train = tracks.loc[small & train, ('track', 'genre_top')]
y_test = tracks.loc[small & test, ('track', 'genre_top')]
enc = skl.preprocessing.LabelEncoder()
y_train = enc.fit_transform(y_train)
y_test = enc.transform(y_test)

X_train = features.loc[small & train, 'mfcc']
X_test = features.loc[small & test, 'mfcc']

print('{} training examples, {} testing examples'.format(y_train.size, y_test.size))
print('{} features, {} classes'.format(X_train.shape[1], np.unique(y_train).size))

# Accuracy: 46.93%
# Out:
# 6400 training examples, 800 testing examples
# 140 features, 8 classes

# %%
# medium
medium = tracks['set', 'subset'] <= 'medium'

train = tracks['set', 'split'] == 'training'
val = tracks['set', 'split'] == 'validation'
test = tracks['set', 'split'] == 'test'

y_train = tracks.loc[medium & train, ('track', 'genre_top')]
y_test = tracks.loc[medium & test, ('track', 'genre_top')]
enc = skl.preprocessing.LabelEncoder()
y_train = enc.fit_transform(y_train)
y_test = enc.transform(y_test)

X_train = features.loc[medium & train, 'mfcc']
X_test = features.loc[medium & test, 'mfcc']

print('{} training examples, {} testing examples'.format(y_train.size, y_test.size))
print('{} features, {} classes'.format(X_train.shape[1], np.unique(y_train).size))

# Accuracy: 60.89%
# Out:
# 19922 training examples, 2573 testing examples
# 140 features, 16 classes

# %%
# large
large = tracks['set', 'subset'] <= 'large' # level[0]: 'set', level[1]: 'subset';

train = tracks['set', 'split'] == 'training'
val = tracks['set', 'split'] == 'validation'
test = tracks['set', 'split'] == 'test'

y_train = tracks.loc[large & train, ('track', 'genre_top')]
y_test = tracks.loc[large & test, ('track', 'genre_top')]
enc = skl.preprocessing.LabelEncoder()
y_train = enc.fit_transform(y_train)
y_test = enc.transform(y_test)

X_train = features.loc[large & train, 'mfcc']
X_test = features.loc[large & test, 'mfcc']

print('{} training examples, {} testing examples'.format(y_train.size, y_test.size))
print('{} features, {} classes'.format(X_train.shape[1], np.unique(y_train).size))

# Accuracy: 62.23%
# Out:
# 84353 training examples, 11263 testing examples
# 140 features, 17 classes

# %%
# Be sure training samples are shuffled.
X_train, y_train = skl.utils.shuffle(X_train, y_train, random_state=42)

# Standardize features by removing the mean and scaling to unit variance.
scaler = skl.preprocessing.StandardScaler(copy=False)
scaler.fit_transform(X_train)
scaler.transform(X_test)

# Support vector classification.
clf = skl.svm.SVC()
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
print('Accuracy: {:.2%}'.format(score))

# %% [markdown]
# ### PCA-SVM
#
# * with medium subset

# %%
medium = tracks['set', 'subset'] <= 'medium'

train = tracks['set', 'split'] == 'training'
val = tracks['set', 'split'] == 'validation'
test = tracks['set', 'split'] == 'test'

y_train = tracks.loc[medium & train, ('track', 'genre_top')]
y_train = skl.preprocessing.LabelEncoder().fit_transform(y_train)

y_test = tracks.loc[medium & test, ('track', 'genre_top')]
y_test = skl.preprocessing.LabelEncoder().fit_transform(y_test)

X_train = features.loc[medium & train,:]
X_train = skl.decomposition.PCA(n_components=2).fit_transform(X_train)
X_test = features.loc[medium & test,:]
X_test = skl.decomposition.PCA(n_components=2).fit_transform(X_test)

print('{} training examples, {} testing examples'.format(y_train.size, y_test.size))
print('{} features, {} classes'.format(X_train.shape[1], np.unique(y_train).size))

# Accuracy: 60.89%
# Out:
# 19922 training examples, 2573 testing examples
# 100 features, 16 classes

# %%
# Be sure training samples are shuffled.
X_train, y_train = skl.utils.shuffle(X_train, y_train, random_state=42)

# Standardize features by removing the mean and scaling to unit variance.
scaler = skl.preprocessing.StandardScaler(copy=False)
scaler.fit_transform(X_train)
scaler.transform(X_test)

# Support vector classification.
clf = skl.svm.SVC(kernel="linear")
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
score_train = clf.score(X_train, y_train)
print('Test Accuracy: {:.2%}'.format(score))
print('Train Accuracy: {:.2%}'.format(score_train))
# Out:
# Test Accuracy: 16.87%
# Train Accuracy: 65.66%

# %% [markdown]
# ### 5.2 From audio
